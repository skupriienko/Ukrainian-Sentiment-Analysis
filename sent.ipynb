# %%
import pandas as pd

sentiment = pd.read_csv('C:/src/SANDBOX/RawProjects/My_Projects/Ukrainian-Sentiment-Analysis/new_sent.csv')

sentiment.sort_values("word", inplace = True)
sentiment.drop_duplicates(subset ="word", keep = False, inplace = True) 
sentiment.reset_index(drop=True, inplace=True)
sentiment.to_csv('new_sent2.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe0 in position 0: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-28-e729a70d024c> in <module>
#       1 import pandas as pd
#       2
# ----> 3 sentiment = pd.read_csv('C:/src/SANDBOX/RawProjects/My_Projects/Ukrainian-Sentiment-Analysis/new_sent.csv', header=None, names=['word', 'pos_neg'])
#       4
# ...

# %%
se
